# %% [markdown]
# <a href="https://colab.research.google.com/github/DabanAbdullah/DabanAbdullah/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Adjusting the font color of country labels to match the chart colors
import matplotlib.pyplot as plt
import numpy as np
# Data for the charts
# Gender data
gender_labels = ['Male', 'Female']
gender_counts = [6, 5]

# Country data
country_labels = ['Nepal', 'India', 'Iraq', 'Brazil', 'UK', 'Colombia', 'Bolivia']
country_counts = [2, 2, 2, 1,1,2,1]

# Chatbot usage data
chatbot_labels = ['Used Chatbot', 'Did Not Use Chatbot']
chatbot_counts = [8, 3]

# Age data
ages = [28, 25, 26, 31, 39, 29, 35, 33, 31, 23, 21]
age_bins = [20, 25, 30, 35, 40]
age_labels = ['20-25', '26-30', '31-35', '36-40']
# Calculate age distribution
age_distribution, _ = np.histogram(ages, bins=age_bins)

country_colors = [
    'Navy', 'DarkOrange', 'green', 'brown', 'purple', 'DarkKhaki', 'Teal'
]

# Plotting the charts again with updated country label colors
fig, axes = plt.subplots(2, 2, figsize=(8, 6))
fig.tight_layout(pad=3.0)

# Gender pie chart
axes[0, 0].pie(gender_counts, labels=gender_labels, autopct=lambda p: f'{p * sum(gender_counts) / 100:.0f}', colors=['lightblue', 'pink'])
axes[0, 0].set_title('Gender Distribution')

# Country pie chart with colored labels
country_patches, texts, autotexts = axes[0, 1].pie(
    country_counts, labels=country_labels, autopct=lambda p: f'{int(p * sum(country_counts) / 100)}', startangle=140, colors=country_colors
)
for text, color in zip(texts, country_colors):
    text.set_color(color)
axes[0, 1].set_title('Country Distribution')

# Chatbot usage chart
axes[1, 0].bar(chatbot_labels, chatbot_counts, color=['green', 'orange'])
axes[1, 0].set_title('Chatbot Usage')
axes[1, 0].set_ylabel('Number of Participants')

# Age distribution bar chart
axes[1, 1].bar(age_labels, age_distribution, color='purple')
axes[1, 1].set_title('Age Distribution')
axes[1, 1].set_ylabel('Number of Participants')

# Save and show the chart
plt.savefig('/mnt/data/demographic_info_charts_updated.png')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-10-0b9816cf47f8> in <cell line: 55>()
#      53
#      54 # Save and show the chart
# ---> 55 plt.savefig('/mnt/data/demographic_info_charts_updated.png')
#      56 plt.show()
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/pyplot.py in savefig(*args, **kwargs)
#    1117     # savefig default implementation has no return, so mypy is unhappy
#    1118     # presumably this is here because subclasses can return?
# -> 1119     res = fig.savefig(*args, **kwargs)  # type: ignore[func-returns-value]
#    1120     fig.canvas.draw_idle()  # Need this if 'transparent=True', to reset colors.
#    1121     return res
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/figure.py in savefig(self, fname, transparent, **kwargs)
#    3388                 for ax in self.axes:
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Creating the dataset from the provided table
data = {
    "Participant": ["p1", "p2", "p3", "p4", "p5", "p6", "p7", "p8"],
    "CUQ Score": [76.6, 78.1, 70.3, 84.4, 78.1, 79.7, 84.4, 71.9]
}
df = pd.DataFrame(data)

# Calculating statistics
mean_score = df["CUQ Score"].mean()
median_score = df["CUQ Score"].median()
std_dev = df["CUQ Score"].std()
min_score = df["CUQ Score"].min()
max_score = df["CUQ Score"].max()

# Displaying statistics
statistics = {
    "Mean CUQ Score": mean_score,
    "Median CUQ Score": median_score,
    "Standard Deviation": std_dev,
    "Minimum CUQ Score": min_score,
    "Maximum CUQ Score": max_score,
    "Number of Participants": len(df),
}
stats_df = pd.DataFrame(statistics, index=["Value"])
print(stats_df)

# Creating a visualization
plt.figure(figsize=(10, 6))
plt.bar(df["Participant"], df["CUQ Score"], color="skyblue")
plt.axhline(mean_score, color="red", linestyle="--", label=f"Mean: {mean_score:.2f}")
plt.title("CUQ Scores for UI1")
plt.xlabel("Participant")
plt.ylabel("CUQ Score")
plt.legend()
plt.show()
# Out:
#        Mean CUQ Score  Median CUQ Score  Standard Deviation  \
# Value         77.9375              78.1            5.116622
#
#        Minimum CUQ Score  Maximum CUQ Score  Number of Participants
# Value               70.3               84.4                       8

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Creating datasets for three UIs
data_ui1 = {
    "Participant": ["p1", "p2", "p3", "p4", "p5", "p6", "p7", "p8"],
    "CUQ Score": [76.6, 78.1, 70.3, 84.4, 78.1, 79.7, 84.4, 71.9]
}
data_ui2 = {
    "Participant": ["p1", "p2", "p3", "p4", "p5", "p6", "p7", "p8"],
    "CUQ Score": [81.0, 79.0, 73.5, 85.0, 80.0, 78.5, 86.0, 75.5]
}
data_ui3 = {
    "Participant": ["p1", "p2", "p3", "p4", "p5", "p6", "p7", "p8"],
    "CUQ Score": [70.0, 72.5, 68.0, 74.5, 71.0, 73.0, 75.0, 69.5]
}

# Converting datasets to DataFrames
df_ui1 = pd.DataFrame(data_ui1)
df_ui2 = pd.DataFrame(data_ui2)
df_ui3 = pd.DataFrame(data_ui3)

# Function to calculate statistics and create a visualization
def analyze_ui(df, ax, ui_name):
    mean_score = df["CUQ Score"].mean()
    median_score = df["CUQ Score"].median()
    std_dev = df["CUQ Score"].std()
    min_score = df["CUQ Score"].min()
    max_score = df["CUQ Score"].max()

    # Bar chart
    ax.bar(df["Participant"], df["CUQ Score"], color="skyblue")
    ax.axhline(mean_score, color="red", linestyle="--", label=f"Mean: {mean_score:.2f}")
    ax.set_title(f"{ui_name}")
    ax.set_xlabel("Participant")
    ax.set_ylabel("CUQ Score")
    ax.legend()

    # Adding statistics below the chart
    stats_text = (
        f"Mean: {mean_score:.2f}\n"
        f"Median: {median_score:.2f}\n"
        f"Std Dev: {std_dev:.2f}\n"
        f"Min: {min_score:.2f}\n"
        f"Max: {max_score:.2f}"
    )
    ax.text(
        0.5, -0.2, stats_text, fontsize=9, ha="center", va="top", transform=ax.transAxes,
        bbox=dict(facecolor='white', edgecolor='black', boxstyle='round,pad=0.5')
    )

# Create subplots for the three UIs
fig, axes = plt.subplots(1, 3, figsize=(15, 5))  # Adjust size for smaller charts
analyze_ui(df_ui1, axes[0], "UI1")
analyze_ui(df_ui2, axes[1], "UI2")
analyze_ui(df_ui3, axes[2], "UI3")

plt.tight_layout()
plt.show()
